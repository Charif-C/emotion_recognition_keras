# %%
import numpy as np
import tensorflow as tf
import random as rn

# The below is necessary in Python 3.2.3 onwards to
# have reproducible behavior for certain hash-based operations.
# See these references for further details:
# https://docs.python.org/3.4/using/cmdline.html#envvar-PYTHONHASHSEED
# https://github.com/keras-team/keras/issues/2280#issuecomment-306959926

import os
os.environ['PYTHONHASHSEED'] = '0'

# The below is necessary for starting Numpy generated random numbers
# in a well-defined initial state.

np.random.seed(42)

# The below is necessary for starting core Python generated random numbers
# in a well-defined state.

rn.seed(12345)

# Force TensorFlow to use single thread.
# Multiple threads are a potential source of
# non-reproducible results.
# For further details, see: https://stackoverflow.com/questions/42022950/which-seeds-have-to-be-set-where-to-realize-100-reproducibility-of-training-res

session_conf = tf.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)

from keras import backend as K

# The below tf.set_random_seed() will make random number generation
# in the TensorFlow backend have a well-defined initial state.
# For further details, see: https://www.tensorflow.org/api_docs/python/tf/set_random_seed

tf.set_random_seed(1234)

sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
K.set_session(sess)

# Rest of code follows ...
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
import keras

# %%
from keras.models import Model
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.optimizers import Adam, SGD
import numpy as np
from keras.models import load_model
from keras.utils.np_utils import to_categorical
from tqdm import tqdm
from keras.callbacks import ModelCheckpoint

# %%
import itertools
import matplotlib.pyplot as plt
import matplotlib

from sklearn.metrics import confusion_matrix

# %%
def plot_confusion_matrix(y_true, y_pred, cmap=plt.cm.Blues, normalise=False, title='Confusion matrix'):
    cm = confusion_matrix(y_true, y_pred)
    if normalise:
        cm = np.round(cm.astype('float') / cm.sum(axis=1)[:, np.newaxis],2)
    fig = plt.figure(figsize=(7,7))
    matplotlib.rcParams.update({'font.size': 16})
    ax  = fig.add_subplot(111)
    matrix = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    fig.colorbar(matrix) 
    for i in range(0,7):
        for j in range(0,7):  
            ax.text(j,i,cm[i,j],va='center', ha='center')
    # ax.set_title('Confusion Matrix')
    ticks = np.arange(len(class_names))
    ax.set_xticks(ticks)
    ax.set_xticklabels(class_names, rotation=45)
    ax.set_yticks(ticks)
    ax.set_yticklabels(class_names)
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.title(title)
    plt.show()

# %%
# load data
X_train=np.load('images_train.npy')
y_train=np.load('emotions_train.npy')
y_train=to_categorical(y_train)

X_val=np.load('images_val.npy')
y_val=np.load('emotions_val.npy')
y_val=to_categorical(y_val)

X_test=np.load('images_test.npy')
y_test=np.load('emotions_test.npy')
y_test=to_categorical(y_test)

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

from skimage import data
from skimage.util.dtype import dtype_range
from skimage.util import img_as_ubyte
from skimage import exposure
from skimage.morphology import disk
from skimage.filters import rank

selem = disk(30)

for i in range(len(X_train)):
    image = X_train[i]
    X_train[i]=rank.equalize(image, selem=selem)

for i in range(len(X_val)):
    image = X_val[i]
    X_val[i]=rank.equalize(image, selem=selem)

for i in range(len(X_test)):
    image = X_test[i]
    X_test[i]=rank.equalize(image, selem=selem)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:118: UserWarning: Possible sign loss when converting negative image of type int64 to positive image of type uint8.
#   .format(dtypeobj_in, dtypeobj_out))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 210 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 219 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 255 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 235 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 241 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 199 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 250 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 234 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 252 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 254 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 218 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 220 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 200 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 237 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 217 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 245 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 239 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 222 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 213 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 244 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 246 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 230 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 225 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 226 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 208 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 249 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 223 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 211 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 236 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 216 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 248 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 238 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 215 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 231 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 240 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 139 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 232 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 253 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 247 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 197 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 233 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 95 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 251 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 243 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 224 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 227 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 201 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 214 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 196 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 207 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 186 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 164 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 190 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 182 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 228 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 192 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 242 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 212 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 221 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 205 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 198 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 204 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 202 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 189 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 174 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 206 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 194 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 191 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 209 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 229 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 176 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 203 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 179 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 163 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 167 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 193 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 128 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 183 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 195 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 177 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 148 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 184 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 158 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 162 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 149 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 153 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 168 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 172 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 118 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 185 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 156 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 170 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 175 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 169 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 173 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 180 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 133 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 178 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 127 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 165 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 159 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 141 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 107 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 171 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 122 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 188 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 157 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 187 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 129 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 123 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 161 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 138 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 181 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 160 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 130 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 144 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 104 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 150 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 152 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 155 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 113 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 166 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 117 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 136 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 145 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 142 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 146 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 137 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 75 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 120 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 81 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 110 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 135 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 143 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 101 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 119 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 105 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 132 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 151 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 134 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 154 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 0 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 126 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 102 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 116 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 147 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 76 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 112 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 86 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 124 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 121 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 140 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 131 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 98 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 80 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 69 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 78 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 67 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 109 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 108 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 111 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 114 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 84 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 125 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 90 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 82 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 48 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 100 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 71 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 92 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 103 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 99 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 83 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 89 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 68 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 94 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 115 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 93 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 97 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/skimage/util/dtype.py:171: UserWarning: Downcasting int64 to uint8 without scaling because max value 91 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))

# %%
X_train=X_train.reshape(-1, 1, X_train.shape[1], X_train.shape[2])
X_val=X_val.reshape(-1, 1, X_val.shape[1], X_val.shape[2])
X_test=X_test.reshape(-1, 1, X_test.shape[1], X_test.shape[2])

# %%
class_names= ['Angry', 'Disgust', 'Fear', 'Happy','Sad', 'Surprise', 'Neutral']

# %%
# parameters:
batch_size = 128
epochs = 100

# %%
# setup info:
print ('X_train shape: ', X_train.shape) # (n_sample, 1, 48, 48)
print ('y_train shape: ', y_train.shape) # (n_sample, n_categories)
print ('X_val shape: ', X_val.shape) # (n_sample, 1, 48, 48)
print ('y_val shape: ', y_val.shape) # (n_sample, n_categories)
print ('X_test shape: ', X_test.shape) # (n_sample, 1, 48, 48)
print ('y_test shape: ', y_test.shape) # (n_sample, n_categories)
print ('  img size: ', X_train.shape[2], X_train.shape[3])
print ('batch size: ', batch_size)
print ('  nb_epoch: ', epochs)
print ('classes: ', class_names)
# Out:
# X_train shape:  (28709, 1, 48, 48)
# y_train shape:  (28709, 7)
# X_val shape:  (3589, 1, 48, 48)
# y_val shape:  (3589, 7)
# X_test shape:  (3589, 1, 48, 48)
# y_test shape:  (3589, 7)
#   img size:  48 48
# batch size:  128
#   nb_epoch:  100
# classes:  ['Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral']

# %%
model=load_model('equalize.h5')

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# block1_conv1 (Conv2D)        (None, 32, 48, 48)        320
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 32, 48, 48)        9248
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 32, 24, 24)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 64, 24, 24)        18496
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 64, 24, 24)        36928
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 64, 12, 12)        0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 128, 12, 12)       73856
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 128, 12, 12)       147584
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 128, 12, 12)       147584
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 128, 6, 6)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 4608)              0
# _________________________________________________________________
# fc6 (Dense)                  (None, 512)               2359808
# _________________________________________________________________
# fc7 (Dense)                  (None, 512)               262656
# _________________________________________________________________
# predictions (Dense)          (None, 7)                 3591
# =================================================================
# Total params: 3,060,071
# Trainable params: 3,060,071
# Non-trainable params: 0
# _________________________________________________________________

# %%
y_pred=model.predict(X_test, batch_size=batch_size, verbose=1, steps=None)
# Out:
# 3589/3589 [==============================] - 220s 61ms/step

# %%
y_pred_prob=[np.argmax(prob) for prob in y_pred]
y_true = [np.argmax(true) for true in y_test]

# %%
cf_mx=plot_confusion_matrix(y_true, y_pred_prob, title='Confusion matrix, without normalization')
cf_mx_norm=plot_confusion_matrix(y_true, y_pred_prob, normalise=True,title='Normalized confusion matrix')
